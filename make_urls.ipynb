# %%
import pandas as pd

# %%
df = pd.read_csv("organized.csv")

# %%
df
# Out:
#            gbifID                                         identifier  \
# 0      3344144760  https://inaturalist-open-data.s3.amazonaws.com...
# 1      3344144760  https://inaturalist-open-data.s3.amazonaws.com...
# 2      3344144760  https://inaturalist-open-data.s3.amazonaws.com...
# 3      3344133318  https://inaturalist-open-data.s3.amazonaws.com...
# 4      3344133318  https://inaturalist-open-data.s3.amazonaws.com...
# ...           ...                                                ...
# 27366   891034184  https://inaturalist-open-data.s3.amazonaws.com...
# 27367   891034184  https://inaturalist-open-data.s3.amazonaws.com...
# 27368   891030760  https://inaturalist-open-data.s3.amazonaws.com...
# 27369   891024943  https://inaturalist-open-data.s3.amazonaws.com...
# 27370   891019368  https://static.inaturalist.org/photos/85634/or...
#
#            format  taxonID                  scientificName   kingdom  \
# ...

# %%
verbatims = (df['verbatimScientificName'].unique())
print(verbatims)
# Out:
# ['Lynx rufus' 'Puma concolor' 'Panthera tigris' 'Herpailurus yagouaroundi'
#  'Leopardus geoffroyi' 'Acinonyx jubatus' 'Leptailurus serval'
#  'Lynx canadensis' 'Panthera leo' 'Panthera onca' 'Leopardus jacobita'
#  'Felis nigripes' 'Felis chaus' 'Felis silvestris' 'Leopardus pardalis'
#  'Panthera tigris tigris' 'Prionailurus bengalensis' 'Leopardus guigna'
#  'Caracal caracal' 'Felis bieti' 'Leopardus tigrinus' 'Leopardus wiedii'
#  'Panthera pardus' 'Leopardus guttulus' 'Lynx pardinus' 'Lynx lynx'
#  'Panthera pardus tulliana' 'Panthera uncia' 'Prionailurus viverrinus'
#  'Caracal aurata' 'Panthera pardus delacouri' 'Acinonyx jubatus hecki'
#  'Panthera tigris sondaica' 'Lynx lynx dinniki' 'Panthera tigris altaica'
#  'Panthera pardus kotiya' 'Otocolobus manul' 'Neofelis nebulosa'
#  'Neofelis diardi borneensis' 'Pardofelis marmorata' 'Neofelis diardi'
#  'Prionailurus rubiginosus' 'Catopuma temminckii'
#  'Catopuma temminckii moormensis' 'Felis margarita'
# ...

# %%
no_space = (df['verbatimScientificName'].replace(' ', '_', regex=True))
no_space = no_space.unique()
no_space
# Out:
# array(['Lynx_rufus', 'Puma_concolor', 'Panthera_tigris',
#        'Herpailurus_yagouaroundi', 'Leopardus_geoffroyi',
#        'Acinonyx_jubatus', 'Leptailurus_serval', 'Lynx_canadensis',
#        'Panthera_leo', 'Panthera_onca', 'Leopardus_jacobita',
#        'Felis_nigripes', 'Felis_chaus', 'Felis_silvestris',
#        'Leopardus_pardalis', 'Panthera_tigris_tigris',
#        'Prionailurus_bengalensis', 'Leopardus_guigna', 'Caracal_caracal',
#        'Felis_bieti', 'Leopardus_tigrinus', 'Leopardus_wiedii',
#        'Panthera_pardus', 'Leopardus_guttulus', 'Lynx_pardinus',
#        'Lynx_lynx', 'Panthera_pardus_tulliana', 'Panthera_uncia',
#        'Prionailurus_viverrinus', 'Caracal_aurata',
#        'Panthera_pardus_delacouri', 'Acinonyx_jubatus_hecki',
#        'Panthera_tigris_sondaica', 'Lynx_lynx_dinniki',
#        'Panthera_tigris_altaica', 'Panthera_pardus_kotiya',
#        'Otocolobus_manul', 'Neofelis_nebulosa',
#        'Neofelis_diardi_borneensis', 'Pardofelis_marmorata',
# ...

# %%
Lynx = df[df["verbatimScientificName"] == "Lynx rufus"]

# %%
len(Lynx)
# Out:
# 16481

# %%
for i in range(len(no_space)):
    scientific_name = (no_space[i])
    filtering = scientific_name + ' = df[df["verbatimScientificName"] == ' + ('"%s"' %(verbatims[i])) + "]"
    print(filtering)
# Out:
# Lynx_rufus = df[df["verbatimScientificName"] == "Lynx rufus"]
# Puma_concolor = df[df["verbatimScientificName"] == "Puma concolor"]
# Panthera_tigris = df[df["verbatimScientificName"] == "Panthera tigris"]
# Herpailurus_yagouaroundi = df[df["verbatimScientificName"] == "Herpailurus yagouaroundi"]
# Leopardus_geoffroyi = df[df["verbatimScientificName"] == "Leopardus geoffroyi"]
# Acinonyx_jubatus = df[df["verbatimScientificName"] == "Acinonyx jubatus"]
# Leptailurus_serval = df[df["verbatimScientificName"] == "Leptailurus serval"]
# Lynx_canadensis = df[df["verbatimScientificName"] == "Lynx canadensis"]
# Panthera_leo = df[df["verbatimScientificName"] == "Panthera leo"]
# Panthera_onca = df[df["verbatimScientificName"] == "Panthera onca"]
# Leopardus_jacobita = df[df["verbatimScientificName"] == "Leopardus jacobita"]
# Felis_nigripes = df[df["verbatimScientificName"] == "Felis nigripes"]
# Felis_chaus = df[df["verbatimScientificName"] == "Felis chaus"]
# ...

# %%
Lynx_rufus = df[df["verbatimScientificName"] == "Lynx rufus"]
Puma_concolor = df[df["verbatimScientificName"] == "Puma concolor"]
Panthera_tigris = df[df["verbatimScientificName"] == "Panthera tigris"]
Herpailurus_yagouaroundi = df[df["verbatimScientificName"] == "Herpailurus yagouaroundi"]
Leopardus_geoffroyi = df[df["verbatimScientificName"] == "Leopardus geoffroyi"]
Acinonyx_jubatus = df[df["verbatimScientificName"] == "Acinonyx jubatus"]
Leptailurus_serval = df[df["verbatimScientificName"] == "Leptailurus serval"]
Lynx_canadensis = df[df["verbatimScientificName"] == "Lynx canadensis"]
Panthera_leo = df[df["verbatimScientificName"] == "Panthera leo"]
Panthera_onca = df[df["verbatimScientificName"] == "Panthera onca"]
Leopardus_jacobita = df[df["verbatimScientificName"] == "Leopardus jacobita"]
Felis_nigripes = df[df["verbatimScientificName"] == "Felis nigripes"]
Felis_chaus = df[df["verbatimScientificName"] == "Felis chaus"]
Felis_silvestris = df[df["verbatimScientificName"] == "Felis silvestris"]
Leopardus_pardalis = df[df["verbatimScientificName"] == "Leopardus pardalis"]
Panthera_tigris_tigris = df[df["verbatimScientificName"] == "Panthera tigris tigris"]
Prionailurus_bengalensis = df[df["verbatimScientificName"] == "Prionailurus bengalensis"]
Leopardus_guigna = df[df["verbatimScientificName"] == "Leopardus guigna"]
Caracal_caracal = df[df["verbatimScientificName"] == "Caracal caracal"]
Felis_bieti = df[df["verbatimScientificName"] == "Felis bieti"]
Leopardus_tigrinus = df[df["verbatimScientificName"] == "Leopardus tigrinus"]
Leopardus_wiedii = df[df["verbatimScientificName"] == "Leopardus wiedii"]
Panthera_pardus = df[df["verbatimScientificName"] == "Panthera pardus"]
Leopardus_guttulus = df[df["verbatimScientificName"] == "Leopardus guttulus"]
Lynx_pardinus = df[df["verbatimScientificName"] == "Lynx pardinus"]
Lynx_lynx = df[df["verbatimScientificName"] == "Lynx lynx"]
Panthera_pardus_tulliana = df[df["verbatimScientificName"] == "Panthera pardus tulliana"]
Panthera_uncia = df[df["verbatimScientificName"] == "Panthera uncia"]
Prionailurus_viverrinus = df[df["verbatimScientificName"] == "Prionailurus viverrinus"]
Caracal_aurata = df[df["verbatimScientificName"] == "Caracal aurata"]
Panthera_pardus_delacouri = df[df["verbatimScientificName"] == "Panthera pardus delacouri"]
Acinonyx_jubatus_hecki = df[df["verbatimScientificName"] == "Acinonyx jubatus hecki"]
Panthera_tigris_sondaica = df[df["verbatimScientificName"] == "Panthera tigris sondaica"]
Lynx_lynx_dinniki = df[df["verbatimScientificName"] == "Lynx lynx dinniki"]
Panthera_tigris_altaica = df[df["verbatimScientificName"] == "Panthera tigris altaica"]
Panthera_pardus_kotiya = df[df["verbatimScientificName"] == "Panthera pardus kotiya"]
Otocolobus_manul = df[df["verbatimScientificName"] == "Otocolobus manul"]
Neofelis_nebulosa = df[df["verbatimScientificName"] == "Neofelis nebulosa"]
Neofelis_diardi_borneensis = df[df["verbatimScientificName"] == "Neofelis diardi borneensis"]
Pardofelis_marmorata = df[df["verbatimScientificName"] == "Pardofelis marmorata"]
Neofelis_diardi = df[df["verbatimScientificName"] == "Neofelis diardi"]
Prionailurus_rubiginosus = df[df["verbatimScientificName"] == "Prionailurus rubiginosus"]
Catopuma_temminckii = df[df["verbatimScientificName"] == "Catopuma temminckii"]
Catopuma_temminckii_moormensis = df[df["verbatimScientificName"] == "Catopuma temminckii moormensis"]
Felis_margarita = df[df["verbatimScientificName"] == "Felis margarita"]
Prionailurus_planiceps = df[df["verbatimScientificName"] == "Prionailurus planiceps"]
Prionailurus_viverrinus_viverrinus = df[df["verbatimScientificName"] == "Prionailurus viverrinus viverrinus"]

# %%
for i in range(len(no_space)):
    slicer = no_space[i] + ".identifier"
    sliced_file = no_space[i] + " = " + slicer
    print(sliced_file)
# Out:
# Lynx_rufus = Lynx_rufus.identifier
# Puma_concolor = Puma_concolor.identifier
# Panthera_tigris = Panthera_tigris.identifier
# Herpailurus_yagouaroundi = Herpailurus_yagouaroundi.identifier
# Leopardus_geoffroyi = Leopardus_geoffroyi.identifier
# Acinonyx_jubatus = Acinonyx_jubatus.identifier
# Leptailurus_serval = Leptailurus_serval.identifier
# Lynx_canadensis = Lynx_canadensis.identifier
# Panthera_leo = Panthera_leo.identifier
# Panthera_onca = Panthera_onca.identifier
# Leopardus_jacobita = Leopardus_jacobita.identifier
# Felis_nigripes = Felis_nigripes.identifier
# Felis_chaus = Felis_chaus.identifier
# Felis_silvestris = Felis_silvestris.identifier
# Leopardus_pardalis = Leopardus_pardalis.identifier
# Panthera_tigris_tigris = Panthera_tigris_tigris.identifier
# Prionailurus_bengalensis = Prionailurus_bengalensis.identifier
# Leopardus_guigna = Leopardus_guigna.identifier
# Caracal_caracal = Caracal_caracal.identifier
# Felis_bieti = Felis_bieti.identifier
# ...

# %%
Lynx_rufus = Lynx_rufus.identifier
Puma_concolor = Puma_concolor.identifier
Panthera_tigris = Panthera_tigris.identifier
Herpailurus_yagouaroundi = Herpailurus_yagouaroundi.identifier
Leopardus_geoffroyi = Leopardus_geoffroyi.identifier
Acinonyx_jubatus = Acinonyx_jubatus.identifier
Leptailurus_serval = Leptailurus_serval.identifier
Lynx_canadensis = Lynx_canadensis.identifier
Panthera_leo = Panthera_leo.identifier
Panthera_onca = Panthera_onca.identifier
Leopardus_jacobita = Leopardus_jacobita.identifier
Felis_nigripes = Felis_nigripes.identifier
Felis_chaus = Felis_chaus.identifier
Felis_silvestris = Felis_silvestris.identifier
Leopardus_pardalis = Leopardus_pardalis.identifier
Panthera_tigris_tigris = Panthera_tigris_tigris.identifier
Prionailurus_bengalensis = Prionailurus_bengalensis.identifier
Leopardus_guigna = Leopardus_guigna.identifier
Caracal_caracal = Caracal_caracal.identifier
Felis_bieti = Felis_bieti.identifier
Leopardus_tigrinus = Leopardus_tigrinus.identifier
Leopardus_wiedii = Leopardus_wiedii.identifier
Panthera_pardus = Panthera_pardus.identifier
Leopardus_guttulus = Leopardus_guttulus.identifier
Lynx_pardinus = Lynx_pardinus.identifier
Lynx_lynx = Lynx_lynx.identifier
Panthera_pardus_tulliana = Panthera_pardus_tulliana.identifier
Panthera_uncia = Panthera_uncia.identifier
Prionailurus_viverrinus = Prionailurus_viverrinus.identifier
Caracal_aurata = Caracal_aurata.identifier
Panthera_pardus_delacouri = Panthera_pardus_delacouri.identifier
Acinonyx_jubatus_hecki = Acinonyx_jubatus_hecki.identifier
Panthera_tigris_sondaica = Panthera_tigris_sondaica.identifier
Lynx_lynx_dinniki = Lynx_lynx_dinniki.identifier
Panthera_tigris_altaica = Panthera_tigris_altaica.identifier
Panthera_pardus_kotiya = Panthera_pardus_kotiya.identifier
Otocolobus_manul = Otocolobus_manul.identifier
Neofelis_nebulosa = Neofelis_nebulosa.identifier
Neofelis_diardi_borneensis = Neofelis_diardi_borneensis.identifier
Pardofelis_marmorata = Pardofelis_marmorata.identifier
Neofelis_diardi = Neofelis_diardi.identifier
Prionailurus_rubiginosus = Prionailurus_rubiginosus.identifier
Catopuma_temminckii = Catopuma_temminckii.identifier
Catopuma_temminckii_moormensis = Catopuma_temminckii_moormensis.identifier
Felis_margarita = Felis_margarita.identifier
Prionailurus_planiceps = Prionailurus_planiceps.identifier
Prionailurus_viverrinus_viverrinus = Prionailurus_viverrinus_viverrinus.identifier

# %%
for i in range(len(no_space)):
    file = no_space[i] 
    file_name = file + '.to_csv(' + ('"%s"'%('urls_folder/urls_' + no_space[i]+ '.csv')) + ', header=None, index=None, sep='"' '"', mode='"'a'"')'
    print(file_name)
    
# test2.to_csv('urls_puma.csv', header=None, index=None, sep=' ', mode='a')
# Out:
# Lynx_rufus.to_csv("urls_folder/urls_Lynx_rufus.csv", header=None, index=None, sep=' ', mode='a')
# Puma_concolor.to_csv("urls_folder/urls_Puma_concolor.csv", header=None, index=None, sep=' ', mode='a')
# Panthera_tigris.to_csv("urls_folder/urls_Panthera_tigris.csv", header=None, index=None, sep=' ', mode='a')
# Herpailurus_yagouaroundi.to_csv("urls_folder/urls_Herpailurus_yagouaroundi.csv", header=None, index=None, sep=' ', mode='a')
# Leopardus_geoffroyi.to_csv("urls_folder/urls_Leopardus_geoffroyi.csv", header=None, index=None, sep=' ', mode='a')
# Acinonyx_jubatus.to_csv("urls_folder/urls_Acinonyx_jubatus.csv", header=None, index=None, sep=' ', mode='a')
# Leptailurus_serval.to_csv("urls_folder/urls_Leptailurus_serval.csv", header=None, index=None, sep=' ', mode='a')
# Lynx_canadensis.to_csv("urls_folder/urls_Lynx_canadensis.csv", header=None, index=None, sep=' ', mode='a')
# Panthera_leo.to_csv("urls_folder/urls_Panthera_leo.csv", header=None, index=None, sep=' ', mode='a')
# ...

# %%
Lynx_rufus.to_csv("urls_folder/urls_Lynx_rufus.csv", header=None, index=None, sep=' ', mode='a')
Puma_concolor.to_csv("urls_folder/urls_Puma_concolor.csv", header=None, index=None, sep=' ', mode='a')
Panthera_tigris.to_csv("urls_folder/urls_Panthera_tigris.csv", header=None, index=None, sep=' ', mode='a')
Herpailurus_yagouaroundi.to_csv("urls_folder/urls_Herpailurus_yagouaroundi.csv", header=None, index=None, sep=' ', mode='a')

# %%
Leopardus_geoffroyi.to_csv("urls_folder/urls_Leopardus_geoffroyi.csv", header=None, index=None, sep=' ', mode='a')
Acinonyx_jubatus.to_csv("urls_folder/urls_Acinonyx_jubatus.csv", header=None, index=None, sep=' ', mode='a')
Leptailurus_serval.to_csv("urls_folder/urls_Leptailurus_serval.csv", header=None, index=None, sep=' ', mode='a')
Lynx_canadensis.to_csv("urls_folder/urls_Lynx_canadensis.csv", header=None, index=None, sep=' ', mode='a')
Panthera_leo.to_csv("urls_folder/urls_Panthera_leo.csv", header=None, index=None, sep=' ', mode='a')
Panthera_onca.to_csv("urls_folder/urls_Panthera_onca.csv", header=None, index=None, sep=' ', mode='a')
Leopardus_jacobita.to_csv("urls_folder/urls_Leopardus_jacobita.csv", header=None, index=None, sep=' ', mode='a')
Felis_nigripes.to_csv("urls_folder/urls_Felis_nigripes.csv", header=None, index=None, sep=' ', mode='a')
Felis_chaus.to_csv("urls_folder/urls_Felis_chaus.csv", header=None, index=None, sep=' ', mode='a')
Felis_silvestris.to_csv("urls_folder/urls_Felis_silvestris.csv", header=None, index=None, sep=' ', mode='a')
Leopardus_pardalis.to_csv("urls_folder/urls_Leopardus_pardalis.csv", header=None, index=None, sep=' ', mode='a')
Panthera_tigris_tigris.to_csv("urls_folder/urls_Panthera_tigris_tigris.csv", header=None, index=None, sep=' ', mode='a')

# %%
Prionailurus_bengalensis.to_csv("urls_folder/urls_Prionailurus_bengalensis.csv", header=None, index=None, sep=' ', mode='a')
Leopardus_guigna.to_csv("urls_folder/urls_Leopardus_guigna.csv", header=None, index=None, sep=' ', mode='a')
Caracal_caracal.to_csv("urls_folder/urls_Caracal_caracal.csv", header=None, index=None, sep=' ', mode='a')
Felis_bieti.to_csv("urls_folder/urls_Felis_bieti.csv", header=None, index=None, sep=' ', mode='a')
Leopardus_tigrinus.to_csv("urls_folder/urls_Leopardus_tigrinus.csv", header=None, index=None, sep=' ', mode='a')
Leopardus_wiedii.to_csv("urls_folder/urls_Leopardus_wiedii.csv", header=None, index=None, sep=' ', mode='a')
Panthera_pardus.to_csv("urls_folder/urls_Panthera_pardus.csv", header=None, index=None, sep=' ', mode='a')
Leopardus_guttulus.to_csv("urls_folder/urls_Leopardus_guttulus.csv", header=None, index=None, sep=' ', mode='a')
Lynx_pardinus.to_csv("urls_folder/urls_Lynx_pardinus.csv", header=None, index=None, sep=' ', mode='a')
Lynx_lynx.to_csv("urls_folder/urls_Lynx_lynx.csv", header=None, index=None, sep=' ', mode='a')
Panthera_pardus_tulliana.to_csv("urls_folder/urls_Panthera_pardus_tulliana.csv", header=None, index=None, sep=' ', mode='a')
Panthera_uncia.to_csv("urls_folder/urls_Panthera_uncia.csv", header=None, index=None, sep=' ', mode='a')
Prionailurus_viverrinus.to_csv("urls_folder/urls_Prionailurus_viverrinus.csv", header=None, index=None, sep=' ', mode='a')
Caracal_aurata.to_csv("urls_folder/urls_Caracal_aurata.csv", header=None, index=None, sep=' ', mode='a')
Panthera_pardus_delacouri.to_csv("urls_folder/urls_Panthera_pardus_delacouri.csv", header=None, index=None, sep=' ', mode='a')
Acinonyx_jubatus_hecki.to_csv("urls_folder/urls_Acinonyx_jubatus_hecki.csv", header=None, index=None, sep=' ', mode='a')
Panthera_tigris_sondaica.to_csv("urls_folder/urls_Panthera_tigris_sondaica.csv", header=None, index=None, sep=' ', mode='a')
Lynx_lynx_dinniki.to_csv("urls_folder/urls_Lynx_lynx_dinniki.csv", header=None, index=None, sep=' ', mode='a')
Panthera_tigris_altaica.to_csv("urls_folder/urls_Panthera_tigris_altaica.csv", header=None, index=None, sep=' ', mode='a')
Panthera_pardus_kotiya.to_csv("urls_folder/urls_Panthera_pardus_kotiya.csv", header=None, index=None, sep=' ', mode='a')
Otocolobus_manul.to_csv("urls_folder/urls_Otocolobus_manul.csv", header=None, index=None, sep=' ', mode='a')
Neofelis_nebulosa.to_csv("urls_folder/urls_Neofelis_nebulosa.csv", header=None, index=None, sep=' ', mode='a')
Neofelis_diardi_borneensis.to_csv("urls_folder/urls_Neofelis_diardi_borneensis.csv", header=None, index=None, sep=' ', mode='a')
Pardofelis_marmorata.to_csv("urls_folder/urls_Pardofelis_marmorata.csv", header=None, index=None, sep=' ', mode='a')
Neofelis_diardi.to_csv("urls_folder/urls_Neofelis_diardi.csv", header=None, index=None, sep=' ', mode='a')
Prionailurus_rubiginosus.to_csv("urls_folder/urls_Prionailurus_rubiginosus.csv", header=None, index=None, sep=' ', mode='a')
Catopuma_temminckii.to_csv("urls_folder/urls_Catopuma_temminckii.csv", header=None, index=None, sep=' ', mode='a')
Catopuma_temminckii_moormensis.to_csv("urls_folder/urls_Catopuma_temminckii_moormensis.csv", header=None, index=None, sep=' ', mode='a')
Felis_margarita.to_csv("urls_folder/urls_Felis_margarita.csv", header=None, index=None, sep=' ', mode='a')
Prionailurus_planiceps.to_csv("urls_folder/urls_Prionailurus_planiceps.csv", header=None, index=None, sep=' ', mode='a')
Prionailurus_viverrinus_viverrinus.to_csv("urls_folder/urls_Prionailurus_viverrinus_viverrinus.csv", header=None, index=None, sep=' ', mode='a')
